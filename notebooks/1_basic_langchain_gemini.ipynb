# %% [markdown]
# ##Import environmental variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash")

# %%
res =llm.invoke("when was your data last updated and till what date do you know all the facts")
res.text
# Out:
# 'My knowledge cutoff is **March 2026**. This means my data was last updated with information up to that date, and I do not have knowledge of events, developments, or real-time facts that occurred after March 2026.'

# %% [markdown]
# #####Static prompts

# %%
prompts = [
    ("system","you are a java developer"),
    ("user", "explain streams to me in simple language")   ## "system", "ai", "user"
]

res = llm.invoke(prompts)
print(res.text)
# Out:
# Imagine you work at a fruit factory, and your job is to process a bucket of apples.
#
# In Java, **a Stream is like an assembly line (or conveyor belt)** for your data.
#
# Instead of dealing with a whole collection of data all at once (like holding a whole bucket of apples), a Stream lets you process items **one by one** as they pass down the line.
#
# ---
#
# ### How the Assembly Line Works (The 3 Steps)
#
# Every Java Stream has three parts:
#
# 1. **The Source (The Bucket):** This is where your data comes from (like a `List` or an `Array`). You put the items onto the conveyor belt using `.stream()`.
# 2. **Intermediate Operations (The Factory Workers):** These are steps along the belt that modify or filter the data. You can chain as many as you want.
#    * *Filter:* "Throw away bad apples."
#    * *Map:* "Peel the remaining apples."
# 3. **Terminal Operation (The Packaging Box):** This is the end of the line. It collects the final results into a list, a single number, or prints them out. **Nothing actually happens on the belt until you add this step!**
#
# ---
#
# ### Let's look at a code example
#
# Imagine we have a list of numbers: `[1, 2, 3, 4, 5, 6]`
# We want to **keep only the even numbers**, **double them**, and **save them in a new list**.
#
# #### The Old Way (Without Streams - using a Loop):
# ```java
# List<Integer> numbers = List.of(1, 2, 3, 4, 5, 6);
# List<Integer> result = new ArrayList<>();
#
# for (Integer n : numbers) {
#     if (n % 2 == 0) {       // Check if even
#         result.add(n * 2);  // Double it and add to new list
#     }
# }
# ```
# *This works, but you have to write a lot of "how-to" code (creating empty lists, managing loops).*
#
# #### The Stream Way:
# ```java
# List<Integer> numbers = List.of(1, 2, 3, 4, 5, 6);
#
# List<Integer> result = numbers.stream() // 1. Put numbers on the belt
#     .filter(n -> n % 2 == 0)            // 2. Keep only evens (2, 4, 6)
#     .map(n -> n * 2)                    // 3. Double them (4, 8, 12)
#     .toList();                          // 4. Pack them into a new List
# ```
# *Notice how it reads almost like a English sentence!*
#
# ---
#
# ### 4 Golden Rules of Streams to Remember
#
# 1. **They don't change the original data:** Your original `numbers` list stays completely untouched. Streams create a *new* result.
# 2. **They are lazy:** If you set up the belt (filter, map) but forget the final box (`.toList()`), Java won't actually do any work.
# 3. **Use once and throw away:** Once items reach the end of the belt, the stream is closed. You can't reuse it. If you need to process the data again, you create a new stream.
# 4. **They don't store data:** A Stream is a process, not a structure. A `List` is a box full of toys; a `Stream` is the conveyor belt moving the toys.
#
# ### Why do developers love Streams?
# They make your code **shorter, cleaner, and easier to read**. Instead of writing complex `if` statements inside nested loops, you just say *what* you want to do with your data step-by-step.
