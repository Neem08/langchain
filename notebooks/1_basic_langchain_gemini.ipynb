# %% [markdown]
# ##Import environmental variables##Import environmental variables

# %%
# Out:
# 10

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_gemini import Gemini
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain_gemini import ChatOpenAI
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain_gemini' (c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_gemini\__init__.py)
