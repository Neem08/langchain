# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
documents = [
    "Machine learning is a subset of artificial intelligence",
    "Deep learning uses neural networks with multiple layers",
    "Python is a programming language popular for data science",
    "India won the cricket world cup in 2011",
    "AI models can understand and generate human language"
]

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
embedding = GoogleGenerativeAIEmbeddings(model = "gemini-embedding-001")

# %%
vector = embedding.embed_documents(documents)

# %%
len(vector[0])
# Out:
# 3072

# %% [markdown]
# storing vector embedding in vector db

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma.from_texts(
    texts= documents,
    embedding = embedding,
    persist_directory= "./vector_db"
)

# %%
query = "Machine learing"
result = vector_store.similarity_search(query=query,k=2)
result
# Out:
# [Document(id='1d6cab41-f446-4723-b489-08b6d58398b3', metadata={}, page_content='Machine learning is a subset of artificial intelligence'),
#  Document(id='1480f2c5-fbac-478d-a02b-f66d56be4505', metadata={}, page_content='Deep learning uses neural networks with multiple layers')]

# %%
print(result[0].page_content)
# Out:
# Machine learning is a subset of artificial intelligence
