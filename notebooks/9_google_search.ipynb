# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.utilities import GoogleSerperAPIWrapper
search = GoogleSerperAPIWrapper()

# %%
from langchain.agents import create_agent

# %%
search.run("What is the CJP protest")
# Out:
# "The CJP began as a satirical internet collective. But outrage over alleged exam irregularities soon turned it into an unlikely rallying point ... CJP has been holding demonstrations calling for education reforms, after a scandal involving the leak of medical school entrance exams. They were initiated by the Cockroach Janta Party (CJP), an Indian youth-based satirical political movement, the conduct of public examinations. Independent satirical commentary for the people the system forgot to count. Five demands. Community funded. One large, stubborn swarm. CJP Warns Government of ... Starting as a satirical online movement just a couple of months ago, the Cockroach Janta Party (CJP) is now one of India's most visible youth ... The movement, which began as a satirical protest, has evolved into a nationwide challenge to Prime Minister Narendra Modi's government. Sonal Pateria from Jist spent a day at Jantar Mantar after the Delhi Police lathi-charged students during the protest. the “Cockroach Janta Party” draws support from young people frustrated by a lack of jobs and a string of controversies in the education system. Cockroach Janta Party is an Indian satirical political movement that led a youth protest in Delhi in 2026 demanding education reforms."
