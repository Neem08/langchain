# %%
from dotenv import load_dotenv
load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
res= llm.invoke("who is the PM of Japan")
print(res.text)
# Out:
# As of the most recent information I have (up to mid‑2024), the Prime Minister of Japan is **Fumio Kishida**.
#
# If you’re looking for the very latest status (e.g., after any election or resignation that may have happened since then), you might want to check a current news source or the official Japanese government website for any updates.
