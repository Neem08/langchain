# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash")

# %%
history = []
while True:
    query = input("User: ")
    if query.lower in ["bye","exit","tata"]:
        print("tata")
        break
    history.append({"role":"user","content":query})
    print("User: ", query)
    res = llm.invoke(history)
    history.append({"role":"ai","content": res.text})
    print("AI:", res.text)
# Out:
# User:  Helloo
# AI: Hello! How can I help you today?
# User:  my Name is neemisha
# AI: Hello Neemisha! It's nice to meet you. How can I help you today?
# User:  do you know who i am
# AI: I know that your name is Neemisha, because you just shared it with me!
#
# Beyond that, I don't have access to any personal information about you or know who you are in real life. I only know what you choose to tell me during our conversation.
#
# If there's anything specific you'd like to share, or if you have a question I can help with, feel free to let me know!
# User:  nice do you i am an indian
# AI: Based on your name, **Neemisha** (which is a popular name of Indian origin, often meaning "moment" or related to nature/spirituality), it is very likely!
#
# However, since I only know what you tell me, I couldn't be 100% sure unless you confirmed it.
#
# Are you from India, or do you have Indian heritage?
# User:  do you know where i am from?
# AI: No, I don't know the exact city, state, or country you are from!
#
# Because I respect your privacy, I don't have access to your location, IP address, or any personal details.
#
# We talked about your name being of Indian origin, so you might be living in India, or you could be living anywhere else in the world!
#
# Where are you from? I'd love to know if you're comfortable sharing!
# User:  tata
# AI: Tata! 👋 Have a wonderful day ahead, Neemisha! Take care, and feel free to reach out whenever you want to chat again!
# User:
# c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_google_genai\chat_models.py:3157: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 9
#       5         print("tata")
#       6         break
#       7     history.append({"role":"user","content":query})
#       8     print("User: ", query)
# ----> 9     res = llm.invoke(history)
#      10     history.append({"role":"ai","content": res.text})
#      11     print("AI:", res.text)
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_google_genai\chat_models.py:2791, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2788         msg = "Tools are already defined.code_execution tool can't be defined"
#    2789         raise ValueError(msg)
# -> 2791 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_google_genai\chat_models.py:3366, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3363     msg = "Client not initialized."
#    3364     raise ValueError(msg)
# -> 3366 request = self._prepare_request(
#    3367     messages,
#    3368     stop=stop,
#    3369     tools=tools,
#    3370     functions=functions,
#    3371     safety_settings=safety_settings,
#    3372     tool_config=tool_config,
#    3373     generation_config=generation_config,
#    3374     cached_content=cached_content or self.cached_content,
#    3375     tool_choice=tool_choice,
#    3376     **kwargs,
#    3377 )
#    3378 try:
#    3379     response: GenerateContentResponse = self.client.models.generate_content(
#    3380         **request,
#    3381     )
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_google_genai\chat_models.py:3050, in ChatGoogleGenerativeAI._prepare_request(self, messages, stop, tools, functions, safety_settings, tool_config, tool_choice, generation_config, cached_content, **kwargs)
#    3041 if (
#    3042     _uses_fixed_sampling_and_disallows_prefill(self.model)
#    3043     and history
#    3044     and history[-1].role == "model"
#    3045 ):
#    3046     msg = (
#    3047         f"Model '{self.model}' does not support model prefilling. The final "
#    3048         "request turn must be a user message or a function response."
#    3049     )
# -> 3050     raise ValueError(msg)
#    3052 # Process tool configuration
#    3053 formatted_tool_config = self._process_tool_config(
#    3054     tool_choice, tool_config, formatted_tools
#    3055 )
#
# ValueError: Model 'gemini-3.6-flash' does not support model prefilling. The final request turn must be a user message or a function response.
