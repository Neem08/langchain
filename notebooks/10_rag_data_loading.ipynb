# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# Text Document Loader

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("C:/Users/rpaul/Downloads/to do LLM.txt")
text = loader.load()
print(text[0].page_content)
# Out:
# to do LLM :
# 1. an extension that will give me a new column of experience required from the job openings listed so I don't have to open each one manually
# 2. a portal using llm which will give me a list of jobs by scrapping the web and based on 24 hrs listing using my resume
# and apply to them using by adding keywords from the JD
# 3. whenever i create a new file the previous one is added to GitHub if not already present

# %% [markdown]
# Pdf data loader

# %%
from langchain_unstructured import UnstructuredLoader

file_paths = [
    "C:/Users/rpaul/Downloads/Neemisha_Paul_Resume_Barclays_aug.pdf"
]


loader = UnstructuredLoader(file_paths)
loader.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_unstructured\document_loaders.py:239, in _SingleDocumentLoader._elements_via_local(self)
#     238 try:
# --> 239     from unstructured.partition.auto import partition  # type: ignore
#     240 except ImportError:
#
# ModuleNotFoundError: No module named 'unstructured'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 9
#       5 ]
#       6
#       7
#       8 loader = UnstructuredLoader(file_paths)
# ----> 9 loader.load()
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_unstructured\document_loaders.py:176, in UnstructuredLoader.lazy_load(self)
#     174 if isinstance(self.file_path, list):
#     175     for f_path in self.file_path:
# --> 176         yield from load_file(f_path=f_path)
#     177     return
#     179 # Call _UnstructuredBaseLoader normally since file and file_path are not lists
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_unstructured\document_loaders.py:215, in _SingleDocumentLoader.lazy_load(self)
#     210 def lazy_load(self) -> Iterator[Document]:
#     211     """Load file."""
#     212     elements_json = (
#     213         self._post_process_elements_json(self._elements_json)
#     214         if self.post_processors
# --> 215         else self._elements_json
#     216     )
#     217     for element in elements_json:
#     218         metadata = self._get_metadata()
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_unstructured\document_loaders.py:234, in _SingleDocumentLoader._elements_json(self)
#     231 if self.partition_via_api:
#     232     return self._elements_via_api
# --> 234 return self._convert_elements_to_dicts(self._elements_via_local)
#
# File c:\Users\rpaul\OneDrive\Desktop\LLM\gen_ai\env\Lib\site-packages\langchain_unstructured\document_loaders.py:241, in _SingleDocumentLoader._elements_via_local(self)
#     239     from unstructured.partition.auto import partition  # type: ignore
#     240 except ImportError:
# --> 241     raise ImportError(
#     242         "unstructured package not found, please install it with "
#     243         "`pip install unstructured`"
#     244     )
#     246 if self.file and self.unstructured_kwargs.get("metadata_filename") is None:
#     247     raise ValueError(
#     248         "If partitioning a fileIO object, metadata_filename must be specified"
#     249         " as well.",
#     250     )
#
# ImportError: unstructured package not found, please install it with `pip install unstructured`
