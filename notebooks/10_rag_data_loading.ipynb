# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# Text Document Loader

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("C:/Users/rpaul/Downloads/to do LLM.txt")
text = loader.load()
print(text[0].page_content)
# Out:
# to do LLM :
# 1. an extension that will give me a new column of experience required from the job openings listed so I don't have to open each one manually
# 2. a portal using llm which will give me a list of jobs by scrapping the web and based on 24 hrs listing using my resume
# and apply to them using by adding keywords from the JD
# 3. whenever i create a new file the previous one is added to GitHub if not already present

# %% [markdown]
# Pdf data loader

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("C:/Users/rpaul/Downloads/Neemisha_Paul_Resume_Barclays_aug.pdf")
docs = loader.load()
print(docs[0].page_content)
# Out:
# Neemisha Paul
# Full Stack Software Engineer
# +91 7715990663 | rpaulneemu@gmail.com | linkedin.com/in/neemisha-paul/ | github.com/neem08
# EXPERIENCE
# Oracle Financial Services Software Ltd Mumbai, India
# Associate T echnical Consultant – Full-Stack Developer July 2025 – June 2026
# • Delivered 20+ production-grade UI enhancements and 5+ core HDFC Flexcube workflows using JavaScript (ES6),
# HTML5 reducing recurring frontend defects by 40% and improving usability across enterprise banking applications.
# • Developed and maintained Java-based backend componentsfor core banking modules; resolved10+ high-priority UAT
# and production incidents through root-cause analysis using Kibana, BareTail, and Java debugging, improving stability
# and eliminating recurring defects.
# • Diagnosed data integrity and transaction processing issues across application and database layers; optimized SQL
# queries reducing execution time by 30%+ while maintaining reconciliation accuracy .
# ...

# %% [markdown]
# CSV Data Loader

# %%
from langchain_community.document_loaders import CSVLoader
loader= CSVLoader("C:/Users/rpaul/Downloads/studperfupdated (1).csv")
doc = loader.load()
print(doc[:5])
# Out:
# [Document(metadata={'source': 'C:/Users/rpaul/Downloads/studperfupdated (1).csv', 'row': 0}, page_content="gender: female\nrace/ethnicity: group B\nparental level of education: bachelor's degree\nlunch: standard\ntest preparation course: none\nmath score: 72\nreading score: 72\nwriting score: 74"), Document(metadata={'source': 'C:/Users/rpaul/Downloads/studperfupdated (1).csv', 'row': 1}, page_content='gender: female\nrace/ethnicity: group C\nparental level of education: some college\nlunch: standard\ntest preparation course: completed\nmath score: 69\nreading score: 90\nwriting score: 88'), Document(metadata={'source': 'C:/Users/rpaul/Downloads/studperfupdated (1).csv', 'row': 2}, page_content="gender: female\nrace/ethnicity: group B\nparental level of education: master's degree\nlunch: standard\ntest preparation course: none\nmath score: 90\nreading score: 95\nwriting score: 93"), Document(metadata={'source': 'C:/Users/rpaul/Downloads/studperfupdated (1).csv', 'row': 3}, page_conte
# ...

# %% [markdown]
# Web Page Loader

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader("https://docs.langchain.com/oss/python/integrations/document_loaders#webpages")
docs = loader.load()
web_text = docs[0].page_content
print(len(web_text))
print(web_text)
# Out:
# 6441
# ...

# %% [markdown]
# wikipedia loader

# %%
# from langchain_community.document_loaders import WikipediaLoader

# loader = WikipediaLoader(
#     query="Generative artificial intelligence",
#     load_max_docs=2
# )

# docs = loader.load()

# print(len(docs))
# print(docs[0].page_content[:500])
